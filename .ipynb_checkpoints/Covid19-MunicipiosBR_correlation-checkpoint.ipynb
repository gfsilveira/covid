# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
from scipy import stats
from meus.printer import *
from datetime import datetime
import matplotlib.pyplot as plt

data = str(datetime.now().year)+'-'+str(datetime.now().month)+'-'+str(datetime.now().day)
data
# Out:
# '2020-4-10'

# %%
os.chdir('D:\\OneDrive\\Programação\\python\\covid\\data\\results')
directory = os.listdir('..')
printLis(directory)
# Out:
# -------------
# -=< Lista >=-
# -------------
# 0 -> cities.csv
# 1 -> covid19_municipios.csv
# 2 -> COVID19_REGIOES BR.csv
# 3 -> Dados_demográficos_municípios.xlsx
# 4 -> Datalab_COVID.pptx
# 5 -> figures
# 6 -> População residente municipal x população faixa etária.csv
# 7 -> População residente por estado - 2015.csv
# 8 -> População residente x sexo.csv
# 9 -> results

# %%
date = 1
df =  pd.read_csv('..\\'+directory[date])
df.head()
# Out:
#          date state                    city place_type  confirmed  deaths  \
# 0  2020-04-03    AC              Acrelândia       city          9     0.0
# 1  2020-04-03    AC              Porto Acre       city          1     0.0
# 2  2020-04-03    AC              Rio Branco       city         36     0.0
# 3  2020-04-03    AC                     NaN      state         46     0.0
# 4  2020-04-03    AL  Importados/Indefinidos       city          4     0.0
#
#    is_last  estimated_population_2019  city_ibge_code  \
# 0     True                    15256.0       1200013.0
# 1     True                    18504.0       1200807.0
# 2     True                   407319.0       1200401.0
# 3     True                   881935.0            12.0
# 4     True                        NaN             NaN
#
#    confirmed_per_100k_inhabitants  death_rate
# 0                        58.99318         NaN
# 1                         5.40424         NaN
# 2                         8.83828         NaN
# 3                         5.21580         NaN
# 4                             NaN         NaN

# %%
df = df[(df['date'] == '2020-04-03') & (df['place_type'] == 'city')][["estimated_population_2019", "confirmed", "deaths", "confirmed_per_100k_inhabitants", "death_rate", "city"]]
df = df.rename(columns={
    "estimated_population_2019": "Population",
    "confirmed": "Confirmed",
    "deaths": "Deaths",
    "confirmed_per_100k_inhabitants": "Confirmed/100k",
    "death_rate": "Death Rate",
    "city": "City"
})
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 531 entries, 0 to 555
# Data columns (total 6 columns):
# Population        520 non-null float64
# Confirmed         531 non-null int64
# Deaths            531 non-null float64
# Confirmed/100k    515 non-null float64
# Death Rate        81 non-null float64
# City              531 non-null object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 27.0+ KB

# %%
df['City'].to_csv('cities.csv', header=['City'])

# %%
g = 1
print_campo = 's'
col1 = 'Population'
col2 = 'Confirmed'
try:
    os.mkdir(col2)
    print('Directory created')
except FileExistsError:
    print('Directory already exists')
# Out:
# Directory created

# %%
g += 1
plt.figure(figsize=(10, 5))
sns.distplot(
    df[col1].dropna()
)
plt.title(col1 + ' distribuition')
if print_campo == 's':
    plt.savefig('0'+str(g)+'-'+col2+'_'+data+'.png', dpi=150)

# %%
g += 1
plt.figure(figsize=(10, 5))
sns.distplot(
    df[col2].dropna()
)
plt.title(col2 + ' distribuition')
if print_campo == 's':
    plt.savefig('0'+str(g)+'-'+col2+'_'+data+'.png', dpi=150)

# %%
g += 1
plt.figure(figsize=(10, 10))
sns.boxplot(
    x=col1,
    data=df
)
plt.title('All data distribution')
if print_campo == 's':
    plt.savefig('0'+str(g)+'-'+col2+'_'+data+'.png', dpi=150)

# %%
g += 1
plt.figure(figsize=(10, 10))
sns.boxplot(
    x=col2,
    data=df
)
plt.title('All data distribution')
if print_campo == 's':
    plt.savefig('0'+str(g)+'-'+col2+'_'+data+'.png', dpi=150)

# %%
g += 1
corr = df.corr(method='spearman')
mask = np.triu(np.ones_like(corr, dtype=np.bool))
plt.figure(figsize=(15, 10))
sns.heatmap(
    corr,
    mask=mask,
    cmap='coolwarm',
    vmax=1,
    vmin=-1,
    center=0,
    square=True,
    linewidths=.5,
    cbar_kws={"shrink": .5},
    annot=True
)
plt.title('Spearman correlation for all data')
if print_campo == 's':
    plt.savefig(col2+'\\0'+str(g)+'-'+col2+'_'+data+'.png', dpi=150)

# %%
g += 1
df_mold = df.dropna()
pear_pos = stats.spearmanr(df_mold[col1], df_mold[col2])
plt.figure(figsize=(10, 10))
sns.regplot(
    x=col1,
    y=col2,
    data=df
)
plt.title('Spearman correlation for all data')
plt.legend([
    'p = ' + str(round(pear_pos[1], 4)) + '\nR = ' + str(round(pear_pos[0], 4))
])
if print_campo == 's':
    plt.savefig(col2+'\\0'+str(g)+'-'+col2+'_'+data+'.png', dpi=150)

# %%
g += 1
df_mod = df[df['Population'] < 6000000]
corr = df_mod.corr(method='spearman')
mask = np.triu(np.ones_like(corr, dtype=np.bool))
plt.figure(figsize=(15, 10))
sns.heatmap(
    corr,
    mask=mask,
    cmap='coolwarm',
    vmax=1,
    vmin=-1,
    center=0,
    square=True,
    linewidths=.5,
    cbar_kws={"shrink": .5},
    annot=True
)
plt.title('Spearman correlation for < 6E7 '+col1+' data')
if print_campo == 's':
    plt.savefig(col2+'\\0'+str(g)+'-'+col2+'_'+data+'.png', dpi=150)

# %%
g += 1
df_mold = df_mod
pear_pos = stats.spearmanr(df_mold[col1], df_mold[col2])
plt.figure(figsize=(10, 10))
sns.regplot(
    x=col1,
    y=col2,
    data=df_mold
)
plt.title('Spearman correlation for < 6E7 '+col1+' data')
plt.legend([
    'p = ' + str(round(pear_pos[1], 4)) + '\nR = ' + str(round(pear_pos[0], 4))
])
if print_campo == 's':
    plt.savefig(col2+'\\0'+str(g)+'-'+col2+'_'+data+'.png', dpi=150)

# %%
minimus = df[col1].min()
maximus = df[col1].max()
q2 = df[col1].median()
q1 = df[df[col1] < q2][col1].median()
q3 = df[df[col1] > q2][col1].median()
qi = q3 - q1
minor = q1 - (qi * 1.5)
major = q3 + (qi * 1.5)
list_quartil = {
    'minimus': minimus,
    'minor': minor,
    'q1': q1,
    'q2': q2,
    'q3': q3,
    'major': major,
    'maximus': maximus,
    'qi': qi
}
for k, v in list_quartil.items():
    print(f'{k} - {v}')
# Out:
# minimus - 1930.0
# minor - -238206.75
# q1 - 33240.0
# q2 - 89833.0
# q3 - 214204.5
# major - 485651.25
# maximus - 12252023.0
# qi - 180964.5

# %%
g += 1
inic = minimus
end = q1
df_mold = df[(df[col1] > inic) & (df[col1] < end)]
pear_pos = stats.spearmanr(df_mold[col1], df_mold[col2])
plt.figure(figsize=(10, 10))
sns.regplot(
    x=col1,
    y=col2,
    data=df_mold
)
plt.title('Spearman correlation in '+col1+' data (' + str(inic) + ' - ' + str(end) + ')')
plt.legend([
    'p = ' + str(round(pear_pos[1], 4)) + '\nR = ' + str(round(pear_pos[0], 4))
])
if print_campo == 's':
    plt.savefig(col2+'\\0'+str(g)+'-'+col2+'_'+data+'.png', dpi=150)

# %%
g += 1
inic = q1
end = q2
df_mold = df[(df[col1] > inic) & (df[col1] < end)]
pear_pos = stats.spearmanr(df_mold[col1], df_mold[col2])
plt.figure(figsize=(10, 10))
sns.regplot(
    x=col1,
    y=col2,
    data=df_mold
)
plt.title('Spearman correlation in '+col1+' data (' + str(inic) + ' - ' + str(end) + ')')
plt.legend([
    'p = ' + str(round(pear_pos[1], 4)) + '\nR = ' + str(round(pear_pos[0], 4))
])
if print_campo == 's':
    plt.savefig(col2+'\\0'+str(g)+'-'+col2+'_'+data+'.png', dpi=150)

# %%
g += 1
inic = q2
end = q3
df_mold = df[(df[col1] > inic) & (df[col1] < end)]
pear_pos = stats.spearmanr(df_mold[col1], df_mold[col2])
plt.figure(figsize=(10, 10))
sns.regplot(
    x=col1,
    y=col2,
    data=df_mold
)
plt.title('Spearman correlation in '+col1+' data (' + str(inic) + ' - ' + str(end) + ')')
plt.legend([
    'p = ' + str(round(pear_pos[1], 4)) + '\nR = ' + str(round(pear_pos[0], 4))
])
if print_campo == 's':
    plt.savefig(col2+'\\0'+str(g)+'-'+col2+'_'+data+'.png', dpi=150)

# %%
g += 1
inic = q3
end = major
df_mold = df[(df[col1] > inic) & (df[col1] < end)]
pear_pos = stats.spearmanr(df_mold[col1], df_mold[col2])
plt.figure(figsize=(10, 10))
sns.regplot(
    x=col1,
    y=col2,
    data=df_mold
)
plt.title('Spearman correlation in '+col1+' data (' + str(inic) + ' - ' + str(end) + ')')
plt.legend([
    'p = ' + str(round(pear_pos[1], 4)) + '\nR = ' + str(round(pear_pos[0], 4))
])
if print_campo == 's':
    plt.savefig(col2+'\\0'+str(g)+'-'+col2+'_'+data+'.png', dpi=150)

# %%
g += 1
inic = major
end = maximus
df_mold = df[(df[col1] > inic) & (df[col1] < end)]
pear_pos = stats.spearmanr(df_mold[col1], df_mold[col2])
plt.figure(figsize=(10, 10))
sns.regplot(
    x=col1,
    y=col2,
    data=df_mold
)
plt.title('Spearman correlation in '+col1+' data (' + str(inic) + ' - ' + str(end) + ')')
plt.legend([
    'p = ' + str(round(pear_pos[1], 4)) + '\nR = ' + str(round(pear_pos[0], 4))
])
if print_campo == 's':
    plt.savefig(col2+'\\0'+str(g)+'-'+col2+'_'+data+'.png', dpi=150)
