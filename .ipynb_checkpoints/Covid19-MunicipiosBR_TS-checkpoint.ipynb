# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
from scipy import stats
from meus.printer import *
import statsmodels.api as sm
from datetime import datetime
import matplotlib.pyplot as plt
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.seasonal import seasonal_decompose

data = str(datetime.now().year)+'-'+str(datetime.now().month)+'-'+str(datetime.now().day)
data
# Out:
# '2020-4-10'

# %%
os.chdir('D:\\OneDrive\\Programação\\python\\covid\\data\\results')
directory = os.listdir('..')
printLis(directory)
# Out:
# -------------
# -=< Lista >=-
# -------------
# 0 -> cities.csv
# 1 -> covid19_municipios.csv
# 2 -> COVID19_REGIOES BR.csv
# 3 -> Dados_demográficos_municípios.xlsx
# 4 -> Datalab_COVID.pptx
# 5 -> figures
# 6 -> results

# %%
date = 1
df_cov =  pd.read_csv('..\\'+directory[date])
df_cov.head()
# Out:
#          date state                    city place_type  confirmed  deaths  \
# 0  2020-04-03    AC              Acrelândia       city          9     0.0
# 1  2020-04-03    AC              Porto Acre       city          1     0.0
# 2  2020-04-03    AC              Rio Branco       city         36     0.0
# 3  2020-04-03    AC                     NaN      state         46     0.0
# 4  2020-04-03    AL  Importados/Indefinidos       city          4     0.0
#
#    is_last  estimated_population_2019  city_ibge_code  \
# 0     True                    15256.0       1200013.0
# 1     True                    18504.0       1200807.0
# 2     True                   407319.0       1200401.0
# 3     True                   881935.0            12.0
# 4     True                        NaN             NaN
#
#    confirmed_per_100k_inhabitants  death_rate
# 0                        58.99318         NaN
# 1                         5.40424         NaN
# 2                         8.83828         NaN
# 3                         5.21580         NaN
# 4                             NaN         NaN

# %%
df_cov.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5155 entries, 0 to 5154
# Data columns (total 11 columns):
# date                              5155 non-null object
# state                             5155 non-null object
# city                              4607 non-null object
# place_type                        5155 non-null object
# confirmed                         5155 non-null int64
# deaths                            4825 non-null float64
# is_last                           5155 non-null bool
# estimated_population_2019         5009 non-null float64
# city_ibge_code                    5009 non-null float64
# confirmed_per_100k_inhabitants    4962 non-null float64
# death_rate                        549 non-null float64
# dtypes: bool(1), float64(5), int64(1), object(4)
# memory usage: 327.3+ KB

# %%
df_cov['date'] = pd.to_datetime(df_cov['date'])
df_cov.head()
# Out:
#         date state                    city place_type  confirmed  deaths  \
# 0 2020-04-03    AC              Acrelândia       city          9     0.0
# 1 2020-04-03    AC              Porto Acre       city          1     0.0
# 2 2020-04-03    AC              Rio Branco       city         36     0.0
# 3 2020-04-03    AC                     NaN      state         46     0.0
# 4 2020-04-03    AL  Importados/Indefinidos       city          4     0.0
#
#    is_last  estimated_population_2019  city_ibge_code  \
# 0     True                    15256.0       1200013.0
# 1     True                    18504.0       1200807.0
# 2     True                   407319.0       1200401.0
# 3     True                   881935.0            12.0
# 4     True                        NaN             NaN
#
#    confirmed_per_100k_inhabitants  death_rate
# 0                        58.99318         NaN
# 1                         5.40424         NaN
# 2                         8.83828         NaN
# 3                         5.21580         NaN
# 4                             NaN         NaN

# %%
df_cov = df_cov[['confirmed', 'deaths', 'confirmed_per_100k_inhabitants', 'date']]
group = df_cov.groupby('date')
df = pd.DataFrame()
df['Confirmed'] = group.sum()['confirmed']
df['Deaths'] = group.sum()['deaths']
df['Confirmed/100k'] = group.sum()['confirmed_per_100k_inhabitants']
df.index.name = 'Date'
df.head()
# Out:
#             Confirmed  Deaths  Confirmed/100k
# Date
# 2020-02-26          2     0.0         0.01034
# 2020-02-27          2     0.0         0.01034
# 2020-02-28          4     0.0         0.02068
# 2020-02-29          4     0.0         0.02068
# 2020-03-01          4     0.0         0.02068

# %%
df.tail()
# Out:
#             Confirmed  Deaths  Confirmed/100k
# Date
# 2020-03-30       9320   332.0      1606.29663
# 2020-03-31      11648   404.0      1919.60469
# 2020-04-01      13862   488.0      2153.96491
# 2020-04-02      16196   589.0      2651.23592
# 2020-04-03      17108   686.0      3099.90011

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 38 entries, 2020-02-26 to 2020-04-03
# Data columns (total 3 columns):
# Confirmed         38 non-null int64
# Deaths            38 non-null float64
# Confirmed/100k    38 non-null float64
# dtypes: float64(2), int64(1)
# memory usage: 1.2 KB

# %%
g = 1
campo = 'Confirmed'
print_campo = 'n'
figsize=(30, 5)
first = '2020-' + str(df.tail(1).index.month[0] - 1) + '-' + str(df.tail(1).index.day[0])
last = '2020-' + str(df.tail(1).index.month[0] + 1) + '-' + str(df.tail(1).index.day[0])
start = '2020-' + str(df.head(1).index.month[0]) + '-' + str(df.head(1).index.day[0])
end = '2020-' + str(df.tail(1).index.month[0]) + '-' + str(df.tail(1).index.day[0])
try:
    os.mkdir('data\\results\\ts')
    print('Directory created')
except FileExistsError:
    print('Directory already exists')
# Out:
# Directory already exists

# %%
df.plot(figsize=figsize)
plt.title('Time Series for day ('+str(start)+' at '+str(end)+')')
if print_campo == 's':
    g += 1
    plt.savefig('data\\results\\ts\\0'+str(g)+'-'+campo+'_'+data+'.png', dpi=150)

# %%
dec = seasonal_decompose(df)
dec.trend.plot(figsize=figsize)
plt.title('Time Series trend for day.')
if print_campo == 's':
    g += 1
    plt.savefig('data\\results\\ts\\0'+str(g)+'-'+campo+'_'+data+'.png', dpi=150)

# %%
dec.seasonal.plot(figsize=figsize)
plt.title('Time Series seasonal for day.')
if print_campo == 's':
    g += 1
    plt.savefig('data\\results\\ts\\0'+str(g)+'-'+campo+'_'+data+'.png', dpi=150)

# %%
dec.resid.plot(figsize=figsize)
plt.title('Time Series resid for day.')
if print_campo == 's':
    g += 1
    plt.savefig('data\\results\\ts\\0'+str(g)+'-'+campo+'_'+data+'.png', dpi=150)

# %%
for p in range(3):
    for q in range(3):
        for d in range(3):
            test = (p, q, d)
            modelo = ARIMA(df[campo], order=test, freq='D')
            try:
                results = modelo.fit()
                print(f'({p}, {q}, {d})')
                print(results.summary().tables[1])
                print()
            except: 
                print('Não')
# Out:
# (0, 0, 0)
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       3065.2368    767.649      3.993      0.000    1560.672    4569.801
# ==============================================================================
#
# (0, 0, 1)
# ===================================================================================
#                       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const            3195.0260    809.034      3.949      0.000    1609.349    4780.703
# ma.L1.Confirmed     1.0000      0.078     12.843      0.000       0.847       1.153
# ===================================================================================
#
# Não
# (0, 1, 0)
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        462.3243    122.117      3.786      0.001     222.980     701.669
# ==============================================================================
#
# (0, 1, 1)
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const               453.8862    149.943      3.027      0.005     160.003     747.769
# ma.L1.D.Confirmed     0.5862      0.111      5.284      0.000       0.369       0.804
# =====================================================================================
#
# (0, 1, 2)
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const               447.9636    177.170      2.528      0.016     100.717     795.211
# ma.L1.D.Confirmed     0.6651      0.182      3.662      0.001       0.309       1.021
# ma.L2.D.Confirmed     0.3831      0.172      2.224      0.033       0.046       0.721
# =====================================================================================
#
# (0, 2, 0)
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         25.3333     92.423      0.274      0.786    -155.812     206.478
# ==============================================================================
#
# (0, 2, 1)
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 50.2994     28.051      1.793      0.082      -4.679     105.278
# ma.L1.D2.Confirmed    -0.7015      0.172     -4.083      0.000      -1.038      -0.365
# ======================================================================================
#
# (0, 2, 2)
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 47.6985     16.680      2.860      0.007      15.006      80.391
# ma.L1.D2.Confirmed    -0.4904      0.176     -2.785      0.009      -0.835      -0.145
# ma.L2.D2.Confirmed    -0.3549      0.216     -1.640      0.110      -0.779       0.069
# ======================================================================================
#
# (1, 0, 0)
# ===================================================================================
#                       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const            8043.9605   7925.293      1.015      0.317   -7489.328    2.36e+04
# ar.L1.Confirmed     0.9944      0.008    132.415      0.000       0.980       1.009
# ===================================================================================
#
# Não
# Não
# (1, 1, 0)
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const               461.4139    275.926      1.672      0.103     -79.391    1002.219
# ar.L1.D.Confirmed     0.7140      0.110      6.491      0.000       0.498       0.930
# =====================================================================================
#
# (1, 1, 1)
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const               462.1938    278.177      1.662      0.106     -83.023    1007.410
# ar.L1.D.Confirmed     0.7182      0.163      4.397      0.000       0.398       1.038
# ma.L1.D.Confirmed    -0.0084      0.244     -0.034      0.973      -0.486       0.470
# =====================================================================================
#
# (1, 1, 2)
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const               452.5264    256.633      1.763      0.087     -50.466     955.518
# ar.L1.D.Confirmed     0.6102      0.257      2.376      0.023       0.107       1.114
# ma.L1.D.Confirmed     0.1009      0.284      0.355      0.725      -0.456       0.658
# ma.L2.D.Confirmed     0.1505      0.278      0.542      0.591      -0.394       0.695
# =====================================================================================
#
# (1, 2, 0)
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 32.1784     76.320      0.422      0.676    -117.406     181.763
# ar.L1.D2.Confirmed    -0.1985      0.179     -1.108      0.276      -0.550       0.153
# ======================================================================================
#
# (1, 2, 1)
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 46.1871     13.209      3.497      0.001      20.297      72.077
# ar.L1.D2.Confirmed     0.4798      0.155      3.090      0.004       0.175       0.784
# ma.L1.D2.Confirmed    -1.0000      0.098    -10.240      0.000      -1.191      -0.809
# ======================================================================================
#
# (1, 2, 2)
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 46.2326     12.653      3.654      0.001      21.434      71.031
# ar.L1.D2.Confirmed     0.3758      0.291      1.293      0.205      -0.194       0.945
# ma.L1.D2.Confirmed    -0.8631      0.311     -2.777      0.009      -1.472      -0.254
# ma.L2.D2.Confirmed    -0.1369      0.294     -0.466      0.644      -0.713       0.439
# ======================================================================================
# (2, 0, 0)
# ===================================================================================
#                       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const            3065.2592        nan        nan        nan         nan         nan
# ar.L1.Confirmed     1.7851   1.78e-05      1e+05      0.000       1.785       1.785
# ar.L2.Confirmed    -0.7851   7.82e-06     -1e+05      0.000      -0.785      -0.785
# ===================================================================================
#
# Não
# Não
# (2, 1, 0)
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const               462.6190    278.471      1.661      0.106     -83.174    1008.412
# ar.L1.D.Confirmed     0.7092      0.171      4.153      0.000       0.375       1.044
# ar.L2.D.Confirmed     0.0069      0.186      0.037      0.971      -0.359       0.372
# =====================================================================================
#
# Não
# (2, 1, 2)
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const               449.7501    251.190      1.790      0.083     -42.573     942.073
# ar.L1.D.Confirmed     0.7093      0.804      0.883      0.384      -0.866       2.284
# ar.L2.D.Confirmed    -0.0872      0.669     -0.130      0.897      -1.398       1.223
# ma.L1.D.Confirmed     0.0058      0.778      0.007      0.994      -1.519       1.530
# ma.L2.D.Confirmed     0.1727      0.324      0.533      0.598      -0.463       0.808
# =====================================================================================
#
# (2, 2, 0)
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 36.1446     67.342      0.537      0.595     -95.843     168.132
# ar.L1.D2.Confirmed    -0.2255      0.182     -1.238      0.225      -0.583       0.132
# ar.L2.D2.Confirmed    -0.1322      0.178     -0.741      0.464      -0.482       0.218
# ======================================================================================
#
# (2, 2, 1)
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 46.3024     12.056      3.841      0.001      22.673      69.932
# ar.L1.D2.Confirmed     0.5323      0.175      3.035      0.005       0.189       0.876
# ar.L2.D2.Confirmed    -0.1155      0.184     -0.626      0.536      -0.477       0.246
# ma.L1.D2.Confirmed    -1.0000      0.110     -9.079      0.000      -1.216      -0.784
# ======================================================================================
#
# Não

# %%
test = (1,2,2)
modelo = ARIMA(df[campo], order=test, freq='D')
results = modelo.fit()
plt.figure(figsize=figsize)
results.plot_predict(
   first, last,
    ax = df['Confirmed'].plot(),
    plot_insample=True,
)
plt.title('ARIMA'+str(test)+' model forecast for day to ' + last)
if print_campo == 's':
    g += 1
    plt.savefig('data\\results\\ts\\0'+str(g)+'-'+campo+'_'+data+'.png', dpi=150)

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:           D2.Confirmed   No. Observations:                   36
# Model:                 ARIMA(1, 2, 2)   Log Likelihood                -274.185
# Method:                       css-mle   S.D. of innovations            473.196
# Date:                Thu, 09 Apr 2020   AIC                            558.370
# Time:                        17:00:26   BIC                            566.287
# Sample:                    02-28-2020   HQIC                           561.133
#                          - 04-03-2020
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 46.2326     12.653      3.654      0.001      21.434      71.031
# ar.L1.D2.Confirmed     0.3758      0.291      1.293      0.205      -0.194       0.945
# ma.L1.D2.Confirmed    -0.8631      0.311     -2.777      0.009      -1.472      -0.254
# ma.L2.D2.Confirmed    -0.1369      0.294     -0.466      0.644      -0.713       0.439
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            2.6608           +0.0000j            2.6608            0.0000
# MA.1            1.0000           +0.0000j            1.0000            0.0000
# MA.2           -7.3062           +0.0000j            7.3062            0.5000
# -----------------------------------------------------------------------------
# """

# %%
pred = results.forecast(steps=30)
pred
# Out:
# (array([18203.76150557, 19520.47357848, 20949.08251877, 22448.60268111,
#         24003.63043294, 25608.37662798, 27260.66553174, 28959.67943807,
#         30705.1110285 , 32496.84480356, 34334.8373551 , 36219.07236902,
#         38149.543714  , 40126.2490857 , 42149.1876181 , 44218.35898571,
#         46333.76306619, 48495.39981358, 50703.2692106 , 52957.37125076,
#         55257.70593161, 57604.27325223, 59997.07321229, 62436.10581165,
#         64921.37105027, 67452.86892812, 70030.5994452 , 72654.5626015 ,
#         75324.75839703, 78041.18683179]),
#  array([ 473.19641187,  858.07340386, 1177.9267683 , 1447.4855473 ,
#         1680.69984417, 1887.48017183, 2074.49735815, 2246.25792495,
#         2405.87880527, 2555.5816244 , 2696.99918847, 2831.36633629,
#         2959.64100636, 3082.58297145, 3200.80644923, 3314.81621753,
#         3425.03304728, 3531.81203805, 3635.45612079, 3736.22619252,
#         3834.3488538 , 3930.02240667, 4023.42156799, 4114.70121914,
#         4203.99942244, 4291.43987223, 4377.13390498, 4461.18216163,
#         4543.67597308, 4624.69852309]),
#  array([[17276.31358069, 19131.20943044],
#         [17838.68061083, 21202.26654613],
#         [18640.38847648, 23257.77656106],
#         [19611.58314027, 25285.62222196],
#         [20709.51926955, 27297.74159633],
#         [21908.98346967, 29307.7697863 ],
#         [23194.72542374, 31326.60563975],
#         [24557.09480518, 33362.26407095],
#         [25989.67521901, 35420.54683799],
#         [27487.9968602 , 37505.69274693],
#         [29048.81607936, 39620.85863084],
#         [30669.69632285, 41768.44841518],
#         [32348.75393436, 43950.33349364],
#         [34084.4974823 , 46168.00068911],
#         [35875.72225614, 48422.65298007],
#         [37721.43858397, 50715.27938744],
#         [39620.82164767, 53046.70448471],
#         [41573.17541884, 55417.62420833],
#         [43577.90614647, 57828.63227474],
#         [45634.50247533, 60280.24002619],
#         [47742.52027399, 62772.89158922],
#         [49901.57087672, 65306.97562775],
#         [52111.31184441, 67882.83458018],
#         [54371.439615  , 70500.77200831],
#         [56681.68359127, 73161.05850927],
#         [59041.80133673, 75863.93651951],
#         [61451.57463594, 78609.62425446],
#         [63910.80623624, 81398.31896676],
#         [66419.31713237, 84230.19966169],
#         [68976.94428717, 87105.42937641]]))

# %%
import warnings
import itertools
warnings.filterwarnings("ignore")

# %%
p = d = q = range(0, 2)
pdq = list(itertools.product(p, d, q))
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]
y = df[campo]
aic_list = list()
param_list = list()
param_s_list = list()
for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            results = sm.tsa.statespace.SARIMAX(
                            y,
                            order=param,
                            seasonal_order=param_seasonal,
                            enforce_stationarity=False,
                            enforce_invertibility=False
            ).fit()
            print(f'ARIMA{param}x{param_seasonal}12 - AIC:{results.aic}')
            param_list.append(param)
            param_s_list.append(param_seasonal)
            aic_list.append(results.aic)
        except: 
            continue
# Out:
# ARIMA(0, 0, 0)x(0, 0, 0, 12)12 - AIC:747.1622266305048
# ARIMA(0, 0, 0)x(0, 0, 1, 12)12 - AIC:1192.8197853855572
# ARIMA(0, 0, 0)x(0, 1, 0, 12)12 - AIC:509.6891549607982
# ARIMA(0, 0, 0)x(1, 0, 0, 12)12 - AIC:476.53302080186376
# ARIMA(0, 0, 0)x(1, 0, 1, 12)12 - AIC:1021.3895605888526
# ARIMA(0, 0, 0)x(1, 1, 0, 12)12 - AIC:266.7344330481233
# ARIMA(0, 0, 1)x(0, 0, 0, 12)12 - AIC:701.4479905446415
# ARIMA(0, 0, 1)x(0, 0, 1, 12)12 - AIC:2367.1034433349096
# ARIMA(0, 0, 1)x(0, 1, 0, 12)12 - AIC:473.9232047149032
# ARIMA(0, 0, 1)x(1, 0, 0, 12)12 - AIC:467.7340218253825
# ARIMA(0, 0, 1)x(1, 0, 1, 12)12 - AIC:nan
# ARIMA(0, 0, 1)x(1, 1, 0, 12)12 - AIC:263.3488869711146
# ARIMA(0, 1, 0)x(0, 0, 0, 12)12 - AIC:592.8886325413729
# ARIMA(0, 1, 0)x(0, 0, 1, 12)12 - AIC:nan
# ARIMA(0, 1, 0)x(0, 1, 0, 12)12 - AIC:400.27696590292544
# ARIMA(0, 1, 0)x(1, 0, 0, 12)12 - AIC:411.6814262823493
# ARIMA(0, 1, 0)x(1, 0, 1, 12)12 - AIC:nan
# ARIMA(0, 1, 0)x(1, 1, 0, 12)12 - AIC:224.1039317572645
# ARIMA(0, 1, 1)x(0, 0, 0, 12)12 - AIC:558.2641607092695
# ARIMA(0, 1, 1)x(0, 0, 1, 12)12 - AIC:2281.668522835625
# ARIMA(0, 1, 1)x(0, 1, 0, 12)12 - AIC:378.5387055272098
# ARIMA(0, 1, 1)x(1, 0, 0, 12)12 - AIC:410.34438611934854
# ARIMA(0, 1, 1)x(1, 0, 1, 12)12 - AIC:381.88221558639674
# ARIMA(0, 1, 1)x(1, 1, 0, 12)12 - AIC:222.48759865709457
# ARIMA(1, 0, 0)x(0, 0, 0, 12)12 - AIC:568.8224426355846
# ARIMA(1, 0, 0)x(0, 0, 1, 12)12 - AIC:1278.5034961552813
# ARIMA(1, 0, 0)x(0, 1, 0, 12)12 - AIC:398.2254435766073
# ARIMA(1, 0, 0)x(1, 0, 0, 12)12 - AIC:398.1675525096194
# ARIMA(1, 0, 0)x(1, 0, 1, 12)12 - AIC:1075.5397006382796
# ARIMA(1, 0, 0)x(1, 1, 0, 12)12 - AIC:216.82897900594776
# ARIMA(1, 0, 1)x(0, 0, 0, 12)12 - AIC:554.2276321172365
# ARIMA(1, 0, 1)x(0, 0, 1, 12)12 - AIC:2046.8348462254835
# ARIMA(1, 0, 1)x(0, 1, 0, 12)12 - AIC:385.2661952980353
# ARIMA(1, 0, 1)x(1, 0, 0, 12)12 - AIC:395.6351259696635
# ARIMA(1, 0, 1)x(1, 0, 1, 12)12 - AIC:1944.6999486233226
# ARIMA(1, 0, 1)x(1, 1, 0, 12)12 - AIC:220.56490154375868
# ARIMA(1, 1, 0)x(0, 0, 0, 12)12 - AIC:557.894239810034
# ARIMA(1, 1, 0)x(0, 0, 1, 12)12 - AIC:1076.084649467928
# ARIMA(1, 1, 0)x(0, 1, 0, 12)12 - AIC:387.412156460142
# ARIMA(1, 1, 0)x(1, 0, 0, 12)12 - AIC:383.4738530916852
# ARIMA(1, 1, 0)x(1, 0, 1, 12)12 - AIC:387.27680706609067
# ARIMA(1, 1, 0)x(1, 1, 0, 12)12 - AIC:201.77122740729448
# ARIMA(1, 1, 1)x(0, 0, 0, 12)12 - AIC:545.4094113922033
# ARIMA(1, 1, 1)x(0, 0, 1, 12)12 - AIC:2048.4203777364564
# ARIMA(1, 1, 1)x(0, 1, 0, 12)12 - AIC:371.33915974804603
# ARIMA(1, 1, 1)x(1, 0, 0, 12)12 - AIC:385.3790748080381
# ARIMA(1, 1, 1)x(1, 0, 1, 12)12 - AIC:374.57296051994933
# ARIMA(1, 1, 1)x(1, 1, 0, 12)12 - AIC:204.45277888505683

# %%
best = aic_list.index(min(aic_list))
mod = sm.tsa.statespace.SARIMAX(
                                y,
                                order=param_list[best],
                                seasonal_order=param_s_list[best],
                                enforce_stationarity=False,
                                enforce_invertibility=False
)
results = mod.fit()
print(results.summary().tables[1])
# Out:
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.8825      0.403      2.188      0.029       0.092       1.673
# ar.S.L12      -1.8172      1.404     -1.294      0.196      -4.569       0.934
# sigma2      7.124e+05   4.18e+05      1.706      0.088   -1.06e+05    1.53e+06
# ==============================================================================

# %%
results.plot_diagnostics(figsize=(30, 8))
plt.title('SARIMA')
if print_campo == 's':
    g += 1
    plt.savefig('data\\results\\ts\\0'+str(g)+'-'+campo+'_'+data+'.png', dpi=150)

# %%
pred = results.get_prediction(start=pd.to_datetime(first), dynamic=False)
pred_ci = pred.conf_int()
ax = y['2020':].plot(label='observed')
pred.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=.7, figsize=figsize)
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.2)
ax.set_xlabel('Date')
ax.set_ylabel('Retail_sold')
plt.legend()
plt.title('SARIMA model forecast for day to ' + last)
if print_campo == 's':
    g += 1
    plt.savefig('data\\results\\ts\\0'+str(g)+'-'+campo+'_'+data+'.png', dpi=150)

# %%
y_forecasted = pred.predicted_mean
y_truth = y[first:]
mse = ((y_forecasted - y_truth) ** 2).mean()
print(f'The Mean Squared Error is {round(mse, 2)}')
print(f'The Root Mean Squared Error is {round(np.sqrt(mse), 2)}')
# Out:
# The Mean Squared Error is 291668.33
# The Root Mean Squared Error is 540.06

# %%
pred_uc = results.get_forecast(steps=12)
pred_ci = pred_uc.conf_int()
ax = y.plot(label='observed', figsize=figsize)
pred_uc.predicted_mean.plot(ax=ax, label='Forecast')
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.25)
ax.set_xlabel('Date')
ax.set_ylabel('Sales')
plt.legend()
plt.title('SARIMA model forecast for day to ' + last)
if print_campo == 's':
    g += 1
    plt.savefig('data\\results\\ts\\0'+str(g)+'-'+campo+'_'+data+'.png', dpi=150)

# %%
y_forecasted = pred.predicted_mean
y_forecasted.head()
# Out:
# 2020-03-03     4.025297
# 2020-03-04     4.006865
# 2020-03-05     7.224018
# 2020-03-06    20.831882
# 2020-03-07    19.804872
# Freq: D, dtype: float64
