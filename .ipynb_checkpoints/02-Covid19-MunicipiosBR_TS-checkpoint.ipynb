# %%
from scipy import stats
import statsmodels.api as sm
import pmdarima as pm
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.seasonal import seasonal_decompose

data = str(datetime.now().year)+'-'+str(datetime.now().month)+'-'+str(datetime.now().day)
data
# Out:
# '2020-5-4'

# %%
fonte = 15
params = {
        'font.size': 15,
        'legend.fontsize': fonte,
        'axes.labelsize': fonte,
        'axes.titlesize': fonte,
        'xtick.labelsize': fonte,
        'ytick.labelsize': fonte
}
plt.rcParams.update(params)

# %%
os.chdir('E:\\OneDrive\\Programação\\python\\covid\\data\\results')
directory = os.listdir('..')
printLis(directory)
# Out:
# -------------
# -=< Lista >=-
# -------------
# 0 -> .ipynb_checkpoints
# 1 -> 01-caso_full_2020-04-22.csv
# 2 -> 02-caso_full_2020-04-30.csv
# 3 -> artigo
# 4 -> cities.csv
# 5 -> covid19_municipios.csv
# 6 -> COVID19_REGIOES BR.csv
# 7 -> Dados_demográficos_municípios.xlsx
# 8 -> Dados_demográficos_municípios_new.xlsx
# 9 -> Datalab_COVID.pptx
# 10 -> figures
# 11 -> idade.xlsx
# 12 -> obito_cartorio.csv
# 13 -> População residente municipal x população faixa etária.csv
# 14 -> População residente por estado - 2015.csv
# 15 -> População residente x sexo.csv
# 16 -> results

# %%
date = 1
df_cov =  pd.read_csv('..\\'+directory[date])
df_cov.tail()
# Out:
#       city  city_ibge_code        date  estimated_population_2019  \
# 26577  NaN            43.0  2020-04-22                 11377239.0
# 26578  NaN            42.0  2020-04-22                  7164788.0
# 26579  NaN            28.0  2020-04-22                  2298696.0
# 26580  NaN            35.0  2020-04-22                 45919049.0
# 26581  NaN            17.0  2020-04-22                  1572866.0
#
#        is_repeated  is_last  last_available_confirmed  \
# 26577        False     True                       970
# 26578        False     True                      1115
# 26579        False     True                       118
# 26580        False     True                     15914
# 26581        False     True                        37
#
#        last_available_confirmed_per_100k_inhabitants last_available_date  \
# 26577                                        8.52579          2020-04-22
# 26578                                       15.56222          2020-04-22
# 26579                                        5.13335          2020-04-22
# 26580                                       34.65664          2020-04-22
# 26581                                        2.35239          2020-04-22
#
#        last_available_death_rate  last_available_deaths place_type state  \
# 26577                     0.0289                     28      state    RS
# 26578                     0.0350                     39      state    SC
# 26579                     0.0593                      7      state    SE
# 26580                     0.0713                   1134      state    SP
# 26581                     0.0541                      2      state    TO
#
#        new_confirmed  new_deaths
# 26577             52           1
# 26578             24           2
# 26579              1           0
# 26580            529          41
# 26581              1           0

# %%
# df_cov = df_cov[(df_cov['last_available_date'] == '2020-04-10') & (df_cov['place_type'] == 'city')][[
#     "estimated_population_2019",
#     "last_available_confirmed",
#     "last_available_deaths",
#     "last_available_confirmed_per_100k_inhabitants",
#     "last_available_death_rate",
#     "city",
#     "last_available_date"
# ]]
# df_cov = df_cov.rename(columns={
#     "estimated_population_2019": "Population",
#     "last_available_confirmed": "Confirmed",
#     "last_available_deaths": "Deaths",
#     "last_available_confirmed_per_100k_inhabitants": "Confirmed/100k",
#     "last_available_death_rate": "Death Rate",
#     "city": "City",
#     "last_available_date": "Date"
# })
# df_cov.index.name = 'Date'
# df_cov.head()

# %%
df_cov.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26582 entries, 0 to 26581
# Data columns (total 15 columns):
# city                                             25477 non-null object
# city_ibge_code                                   26151 non-null float64
# date                                             26582 non-null object
# estimated_population_2019                        26151 non-null float64
# is_repeated                                      26582 non-null bool
# is_last                                          26582 non-null bool
# last_available_confirmed                         26582 non-null int64
# last_available_confirmed_per_100k_inhabitants    25749 non-null float64
# last_available_date                              26582 non-null object
# last_available_death_rate                        6174 non-null float64
# last_available_deaths                            26582 non-null int64
# place_type                                       26582 non-null object
# state                                            26582 non-null object
# new_confirmed                                    26582 non-null int64
# new_deaths                                       26582 non-null int64
# dtypes: bool(2), float64(4), int64(4), object(5)
# memory usage: 2.7+ MB

# %%
teste = 'date'
df_cov = df_cov[['last_available_confirmed', 'last_available_deaths', 'last_available_confirmed_per_100k_inhabitants', teste]]
df_cov[teste] = pd.to_datetime(df_cov[teste])
group = df_cov.groupby(teste)
df = pd.DataFrame()
df['Confirmed'] = group.sum()['last_available_confirmed']
df['Deaths'] = group.sum()['last_available_deaths']
df['Confirmed/100k'] = group.sum()['last_available_confirmed_per_100k_inhabitants']
df.index.name = 'Date'
df.head()
# Out:
#             Confirmed  Deaths  Confirmed/100k
# Date
# 2020-02-25          2       0         0.01034
# 2020-02-26          2       0         0.01034
# 2020-02-27          2       0         0.01034
# 2020-02-28          4       0         0.02068
# 2020-02-29          4       0         0.02068

# %%
df.tail()
# Out:
#             Confirmed  Deaths  Confirmed/100k
# Date
# 2020-04-18      74348    4750     18378.87578
# 2020-04-19      78212    4981     19895.41860
# 2020-04-20      81859    5196     21028.12907
# 2020-04-21      87289    5542     22462.29763
# 2020-04-22      91859    5834     24121.67284

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 58 entries, 2020-02-25 to 2020-04-22
# Data columns (total 3 columns):
# Confirmed         58 non-null int64
# Deaths            58 non-null int64
# Confirmed/100k    58 non-null float64
# dtypes: float64(1), int64(2)
# memory usage: 1.8 KB

# %%
g = 1
campo = 'Confirmed'
print_campo = 's'
figsize=(30, 5)
first = '2020-' + str(df.tail(1).index.month[0] - 1) + '-' + str(df.tail(1).index.day[0])
last = '2020-' + str(df.tail(1).index.month[0] + 1) + '-' + str(df.tail(1).index.day[0])
start = '2020-' + str(df.head(1).index.month[0]) + '-' + str(df.head(1).index.day[0])
end = '2020-' + str(df.tail(1).index.month[0]) + '-' + str(df.tail(1).index.day[0])
try:
    os.mkdir('ts')
    print('Directory created')
except FileExistsError:
    print('Directory already exists')
# Out:
# Directory already exists

# %%
df.plot(figsize=figsize)
plt.title('Time Series for day ('+str(start)+' at '+str(end)+')')
if print_campo == 's':
    g += 1
    plt.savefig('ts\\0'+str(g)+'-'+campo+'_'+data+'.png', dpi=150)

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=figsize)
dec = seasonal_decompose(df[campo])
dec.trend.plot(figsize=figsize, ax=ax)

campo1 = 'Deaths'
dec = seasonal_decompose(df[campo1])
dec.trend.plot(figsize=figsize, ax=ax)

campo2 = 'Confirmed/100k'
dec = seasonal_decompose(df[campo2])
dec.trend.plot(figsize=figsize, ax=ax)

plt.legend([campo, campo1, campo2])
plt.title('Time Series trend for day.')
if print_campo == 's':
    g += 1
    plt.savefig('ts\\0'+str(g)+'-'+campo+'_'+data+'.png', dpi=150)

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=figsize)
dec = seasonal_decompose(df[campo])
dec.seasonal.plot(figsize=figsize, ax=ax)

campo1 = 'Deaths'
dec = seasonal_decompose(df[campo1])
dec.seasonal.plot(figsize=figsize, ax=ax)

campo2 = 'Confirmed/100k'
dec = seasonal_decompose(df[campo2])
dec.seasonal.plot(figsize=figsize, ax=ax)

plt.legend([campo, campo1, campo2])
plt.title('Time Series trend for day.')
if print_campo == 's':
    g += 1
    plt.savefig('ts\\0'+str(g)+'-'+campo+'_'+data+'.png', dpi=150)

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=figsize)
dec = seasonal_decompose(df[campo])
dec.resid.plot(figsize=figsize, ax=ax)

campo1 = 'Deaths'
dec = seasonal_decompose(df[campo1])
dec.resid.plot(figsize=figsize, ax=ax)

campo2 = 'Confirmed/100k'
dec = seasonal_decompose(df[campo2])
dec.resid.plot(figsize=figsize, ax=ax)

plt.legend([campo, campo1, campo2])
plt.title('Time Series trend for day.')
if print_campo == 's':
    g += 1
    plt.savefig('ts\\0'+str(g)+'-'+campo+'_'+data+'.png', dpi=150)

# %%
for p in range(3):
    for q in range(3):
        for d in range(3):
            test = (p, q, d)
            modelo = ARIMA(df[campo], order=test, freq='D')
            try:
                results = modelo.fit()
                print(f'({p}, {q}, {d})')
                print(results.summary())
                print()
            except: 
                print('Não')
# Out:
# (0, 0, 0)
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:              Confirmed   No. Observations:                   66
# Model:                     ARMA(0, 0)   Log Likelihood                -800.912
# Method:                           css   S.D. of innovations          45075.590
# Date:                Thu, 30 Apr 2020   AIC                           1605.825
# Time:                        17:52:48   BIC                           1610.204
# Sample:                    02-25-2020   HQIC                          1607.555
#                          - 04-30-2020
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       3.292e+04   5548.422      5.934      0.000     2.2e+04    4.38e+04
# ==============================================================================
#
# (0, 0, 1)
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:              Confirmed   No. Observations:                   66
# Model:                     ARMA(0, 1)   Log Likelihood                -759.172
# Method:                       css-mle   S.D. of innovations          23197.655
# Date:                Thu, 30 Apr 2020   AIC                           1524.343
# Time:                        17:52:48   BIC                           1530.912
# Sample:                    02-25-2020   HQIC                          1526.939
#                          - 04-30-2020
# ===================================================================================
#                       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const            3.352e+04   5668.724      5.913      0.000    2.24e+04    4.46e+04
# ma.L1.Confirmed     1.0000      0.037     26.912      0.000       0.927       1.073
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# MA.1           -1.0000           +0.0000j            1.0000            0.5000
# -----------------------------------------------------------------------------
#
# (0, 0, 2)
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:              Confirmed   No. Observations:                   66
# Model:                     ARMA(0, 2)   Log Likelihood                -719.959
# Method:                       css-mle   S.D. of innovations          12296.578
# Date:                Thu, 30 Apr 2020   AIC                           1447.917
# Time:                        17:52:48   BIC                           1456.676
# Sample:                    02-25-2020   HQIC                          1451.378
#                          - 04-30-2020
# ===================================================================================
#                       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const            3.402e+04   5841.422      5.824      0.000    2.26e+04    4.55e+04
# ma.L1.Confirmed     1.9172      0.061     31.302      0.000       1.797       2.037
# ma.L2.Confirmed     1.0000      0.056     17.930      0.000       0.891       1.109
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# MA.1           -0.9586           -0.2848j            1.0000           -0.4540
# MA.2           -0.9586           +0.2848j            1.0000            0.4540
# -----------------------------------------------------------------------------
#
# (0, 1, 0)
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:            D.Confirmed   No. Observations:                   65
# Model:                 ARIMA(0, 1, 0)   Log Likelihood                -614.667
# Method:                           css   S.D. of innovations           3094.811
# Date:                Thu, 30 Apr 2020   AIC                           1233.335
# Time:                        17:52:48   BIC                           1237.683
# Sample:                    02-26-2020   HQIC                          1235.051
#                          - 04-30-2020
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2458.8615    383.864      6.406      0.000    1706.502    3211.221
# ==============================================================================
#
# (0, 1, 1)
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:            D.Confirmed   No. Observations:                   65
# Model:                 ARIMA(0, 1, 1)   Log Likelihood                -591.689
# Method:                       css-mle   S.D. of innovations           2161.629
# Date:                Thu, 30 Apr 2020   AIC                           1189.377
# Time:                        17:52:48   BIC                           1195.900
# Sample:                    02-26-2020   HQIC                          1191.951
#                          - 04-30-2020
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const              2382.2558    455.097      5.235      0.000    1490.283    3274.229
# ma.L1.D.Confirmed     0.7077      0.066     10.785      0.000       0.579       0.836
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# MA.1           -1.4130           +0.0000j            1.4130            0.5000
# -----------------------------------------------------------------------------
#
# (0, 1, 2)
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:            D.Confirmed   No. Observations:                   65
# Model:                 ARIMA(0, 1, 2)   Log Likelihood                -580.755
# Method:                       css-mle   S.D. of innovations           1817.973
# Date:                Thu, 30 Apr 2020   AIC                           1169.510
# Time:                        17:52:49   BIC                           1178.208
# Sample:                    02-26-2020   HQIC                          1172.942
#                          - 04-30-2020
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const              2295.5886    579.333      3.962      0.000    1160.117    3431.061
# ma.L1.D.Confirmed     1.0850      0.111      9.733      0.000       0.867       1.304
# ma.L2.D.Confirmed     0.5154      0.087      5.958      0.000       0.346       0.685
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# MA.1           -1.0525           -0.9123j            1.3929           -0.3863
# MA.2           -1.0525           +0.9123j            1.3929            0.3863
# -----------------------------------------------------------------------------
#
# (0, 2, 0)
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:           D2.Confirmed   No. Observations:                   64
# Model:                 ARIMA(0, 2, 0)   Log Likelihood                -570.817
# Method:                           css   S.D. of innovations           1808.183
# Date:                Thu, 30 Apr 2020   AIC                           1145.634
# Time:                        17:52:49   BIC                           1149.952
# Sample:                    02-27-2020   HQIC                          1147.335
#                          - 04-30-2020
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          9.0625    226.023      0.040      0.968    -433.934     452.059
# ==============================================================================
#
# (0, 2, 1)
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:           D2.Confirmed   No. Observations:                   64
# Model:                 ARIMA(0, 2, 1)   Log Likelihood                -565.331
# Method:                       css-mle   S.D. of innovations           1647.621
# Date:                Thu, 30 Apr 2020   AIC                           1136.661
# Time:                        17:52:49   BIC                           1143.138
# Sample:                    02-27-2020   HQIC                          1139.213
#                          - 04-30-2020
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                128.9205     48.856      2.639      0.008      33.164     224.677
# ma.L1.D2.Confirmed    -0.7781      0.081     -9.549      0.000      -0.938      -0.618
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# MA.1            1.2852           +0.0000j            1.2852            0.0000
# -----------------------------------------------------------------------------
# (0, 2, 2)
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:           D2.Confirmed   No. Observations:                   64
# Model:                 ARIMA(0, 2, 2)   Log Likelihood                -563.548
# Method:                       css-mle   S.D. of innovations           1601.224
# Date:                Thu, 30 Apr 2020   AIC                           1135.095
# Time:                        17:52:49   BIC                           1143.731
# Sample:                    02-27-2020   HQIC                          1138.497
#                          - 04-30-2020
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                123.4407     41.178      2.998      0.003      42.733     204.148
# ma.L1.D2.Confirmed    -0.4187      0.136     -3.069      0.002      -0.686      -0.151
# ma.L2.D2.Confirmed    -0.4008      0.142     -2.832      0.005      -0.678      -0.123
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# MA.1            1.1414           +0.0000j            1.1414            0.0000
# MA.2           -2.1859           +0.0000j            2.1859            0.5000
# -----------------------------------------------------------------------------
#
# (1, 0, 0)
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:              Confirmed   No. Observations:                   66
# Model:                     ARMA(1, 0)   Log Likelihood                -643.400
# Method:                       css-mle   S.D. of innovations           3952.481
# Date:                Thu, 30 Apr 2020   AIC                           1292.801
# Time:                        17:52:49   BIC                           1299.370
# Sample:                    02-25-2020   HQIC                          1295.397
#                          - 04-30-2020
# ===================================================================================
#                       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const            3.292e+04   1.28e+05      0.257      0.797   -2.18e+05    2.84e+05
# ar.L1.Confirmed     0.9990      0.002    518.987      0.000       0.995       1.003
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0010           +0.0000j            1.0010            0.0000
# -----------------------------------------------------------------------------
#
# Não
# Não
# (1, 1, 0)
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:            D.Confirmed   No. Observations:                   65
# Model:                 ARIMA(1, 1, 0)   Log Likelihood                -577.161
# Method:                       css-mle   S.D. of innovations           1722.762
# Date:                Thu, 30 Apr 2020   AIC                           1160.322
# Time:                        17:52:49   BIC                           1166.845
# Sample:                    02-26-2020   HQIC                          1162.895
#                          - 04-30-2020
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const              2189.3087   1145.198      1.912      0.056     -55.238    4433.855
# ar.L1.D.Confirmed     0.8248      0.067     12.321      0.000       0.694       0.956
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.2124           +0.0000j            1.2124            0.0000
# -----------------------------------------------------------------------------
#
# (1, 1, 1)
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:            D.Confirmed   No. Observations:                   65
# Model:                 ARIMA(1, 1, 1)   Log Likelihood                -576.369
# Method:                       css-mle   S.D. of innovations           1695.447
# Date:                Thu, 30 Apr 2020   AIC                           1160.738
# Time:                        17:52:50   BIC                           1169.436
# Sample:                    02-26-2020   HQIC                          1164.170
#                          - 04-30-2020
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const              2855.1040   2264.090      1.261      0.207   -1582.430    7292.638
# ar.L1.D.Confirmed     0.9720      0.040     24.479      0.000       0.894       1.050
# ma.L1.D.Confirmed    -0.5848      0.174     -3.355      0.001      -0.926      -0.243
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0288           +0.0000j            1.0288            0.0000
# MA.1            1.7101           +0.0000j            1.7101            0.0000
# -----------------------------------------------------------------------------
#
# Não
# (1, 2, 0)
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:           D2.Confirmed   No. Observations:                   64
# Model:                 ARIMA(1, 2, 0)   Log Likelihood                -570.397
# Method:                       css-mle   S.D. of innovations           1795.871
# Date:                Thu, 30 Apr 2020   AIC                           1146.795
# Time:                        17:52:50   BIC                           1153.271
# Sample:                    02-27-2020   HQIC                          1149.346
#                          - 04-30-2020
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 37.3025    191.531      0.195      0.846    -338.092     412.697
# ar.L1.D2.Confirmed    -0.1859      0.202     -0.920      0.357      -0.582       0.210
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -5.3778           +0.0000j            5.3778            0.5000
# -----------------------------------------------------------------------------
# (1, 2, 1)
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:           D2.Confirmed   No. Observations:                   64
# Model:                 ARIMA(1, 2, 1)   Log Likelihood                -564.680
# Method:                       css-mle   S.D. of innovations           1631.260
# Date:                Thu, 30 Apr 2020   AIC                           1137.361
# Time:                        17:52:50   BIC                           1145.996
# Sample:                    02-27-2020   HQIC                          1140.763
#                          - 04-30-2020
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                124.6179     43.002      2.898      0.004      40.336     208.900
# ar.L1.D2.Confirmed     0.2820      0.255      1.105      0.269      -0.218       0.782
# ma.L1.D2.Confirmed    -0.8656      0.105     -8.263      0.000      -1.071      -0.660
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            3.5467           +0.0000j            3.5467            0.0000
# MA.1            1.1553           +0.0000j            1.1553            0.0000
# -----------------------------------------------------------------------------
#
# (1, 2, 2)
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:           D2.Confirmed   No. Observations:                   64
# Model:                 ARIMA(1, 2, 2)   Log Likelihood                -563.535
# Method:                       css-mle   S.D. of innovations           1601.115
# Date:                Thu, 30 Apr 2020   AIC                           1137.070
# Time:                        17:52:51   BIC                           1147.864
# Sample:                    02-27-2020   HQIC                          1141.322
#                          - 04-30-2020
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                123.8667     42.112      2.941      0.003      41.328     206.405
# ar.L1.D2.Confirmed    -0.0523      0.328     -0.159      0.873      -0.696       0.591
# ma.L1.D2.Confirmed    -0.3881      0.232     -1.675      0.094      -0.842       0.066
# ma.L2.D2.Confirmed    -0.4160      0.165     -2.516      0.012      -0.740      -0.092
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1          -19.1118           +0.0000j           19.1118            0.5000
# MA.1            1.1526           +0.0000j            1.1526            0.0000
# MA.2           -2.0857           +0.0000j            2.0857            0.5000
# -----------------------------------------------------------------------------
#
# (2, 0, 0)
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:              Confirmed   No. Observations:                   66
# Model:                     ARMA(2, 0)   Log Likelihood                -590.554
# Method:                       css-mle   S.D. of innovations           1740.083
# Date:                Thu, 30 Apr 2020   AIC                           1189.107
# Time:                        17:52:51   BIC                           1197.866
# Sample:                    02-25-2020   HQIC                          1192.568
#                          - 04-30-2020
# ===================================================================================
#                       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const            3.292e+04   4.77e+04      0.690      0.490   -6.06e+04    1.26e+05
# ar.L1.Confirmed     1.8979      0.054     35.079      0.000       1.792       2.004
# ar.L2.Confirmed    -0.9018      0.056    -16.025      0.000      -1.012      -0.791
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0523           -0.0392j            1.0531           -0.0059
# AR.2            1.0523           +0.0392j            1.0531            0.0059
# -----------------------------------------------------------------------------
#
# Não
# Não
# (2, 1, 0)
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:            D.Confirmed   No. Observations:                   65
# Model:                 ARIMA(2, 1, 0)   Log Likelihood                -577.161
# Method:                       css-mle   S.D. of innovations           1722.768
# Date:                Thu, 30 Apr 2020   AIC                           1162.321
# Time:                        17:52:52   BIC                           1171.019
# Sample:                    02-26-2020   HQIC                          1165.753
#                          - 04-30-2020
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const              2189.4789   1149.115      1.905      0.057     -62.746    4441.704
# ar.L1.D.Confirmed     0.8231      0.191      4.316      0.000       0.449       1.197
# ar.L2.D.Confirmed     0.0020      0.206      0.010      0.992      -0.402       0.406
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.2114           +0.0000j            1.2114            0.0000
# AR.2         -411.9815           +0.0000j          411.9815            0.5000
# -----------------------------------------------------------------------------
#
# (2, 1, 1)
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:            D.Confirmed   No. Observations:                   65
# Model:                 ARIMA(2, 1, 1)   Log Likelihood                -576.915
# Method:                       css-mle   S.D. of innovations           1715.612
# Date:                Thu, 30 Apr 2020   AIC                           1163.829
# Time:                        17:52:52   BIC                           1174.701
# Sample:                    02-26-2020   HQIC                          1168.119
#                          - 04-30-2020
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const              2162.5261   1088.549      1.987      0.047      29.009    4296.043
# ar.L1.D.Confirmed     0.4964      0.412      1.204      0.229      -0.312       1.304
# ar.L2.D.Confirmed     0.2377      0.364      0.653      0.514      -0.476       0.952
# ma.L1.D.Confirmed     0.4321      0.356      1.215      0.225      -0.265       1.129
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.2574           +0.0000j            1.2574            0.0000
# AR.2           -3.3453           +0.0000j            3.3453            0.5000
# MA.1           -2.3145           +0.0000j            2.3145            0.5000
# -----------------------------------------------------------------------------
#
# Não
# (2, 2, 0)
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:           D2.Confirmed   No. Observations:                   64
# Model:                 ARIMA(2, 2, 0)   Log Likelihood                -563.654
# Method:                       css-mle   S.D. of innovations           1599.515
# Date:                Thu, 30 Apr 2020   AIC                           1135.308
# Time:                        17:52:52   BIC                           1143.944
# Sample:                    02-27-2020   HQIC                          1138.710
#                          - 04-30-2020
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                107.2763     98.002      1.095      0.274     -84.804     299.356
# ar.L1.D2.Confirmed    -0.3899      0.189     -2.063      0.039      -0.760      -0.019
# ar.L2.D2.Confirmed    -0.6942      0.163     -4.260      0.000      -1.014      -0.375
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -0.2808           -1.1669j            1.2002           -0.2876
# AR.2           -0.2808           +1.1669j            1.2002            0.2876
# -----------------------------------------------------------------------------
#
# (2, 2, 1)
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:           D2.Confirmed   No. Observations:                   64
# Model:                 ARIMA(2, 2, 1)   Log Likelihood                -562.416
# Method:                       css-mle   S.D. of innovations           1568.502
# Date:                Thu, 30 Apr 2020   AIC                           1134.833
# Time:                        17:52:52   BIC                           1145.627
# Sample:                    02-27-2020   HQIC                          1139.085
#                          - 04-30-2020
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                127.4201     55.052      2.315      0.021      19.521     235.319
# ar.L1.D2.Confirmed     0.1533      0.368      0.416      0.677      -0.569       0.875
# ar.L2.D2.Confirmed    -0.5285      0.255     -2.069      0.039      -1.029      -0.028
# ma.L1.D2.Confirmed    -0.6351      0.307     -2.070      0.038      -1.236      -0.034
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            0.1451           -1.3679j            1.3756           -0.2332
# AR.2            0.1451           +1.3679j            1.3756            0.2332
# MA.1            1.5747           +0.0000j            1.5747            0.0000
# -----------------------------------------------------------------------------
#
# Não

# %%
test = (2,2,2) #paramentros guardados em uma variável
modelo = ARIMA(df[campo], order=test, freq='D') #parametros para o modelo preditivo
results = modelo.fit() #ajuste de modelo
plt.figure(figsize=figsize) #plotando imagem
results.plot_predict(
   first, last,               #plotando a primeira e ultima data?
    ax = df[campo].plot(), #filtrando e usando apenas a coluna 'confirmed'
    plot_insample=True,
)
plt.title('ARIMA'+str(test)+' model forecast for day to ' + last)
if print_campo == 's':
    g += 1
    plt.savefig('ts\\0'+str(g)+'-'+campo+'_'+data+'.png', dpi=150)

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:           D2.Confirmed   No. Observations:                   56
# Model:                 ARIMA(2, 2, 2)   Log Likelihood                -444.623
# Method:                       css-mle   S.D. of innovations            649.494
# Date:                Mon, 04 May 2020   AIC                            901.247
# Time:                        11:26:52   BIC                            913.399
# Sample:                    02-27-2020   HQIC                           905.958
#                          - 04-22-2020
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 88.1343     34.870      2.527      0.011      19.790     156.479
# ar.L1.D2.Confirmed     1.2429      0.123     10.114      0.000       1.002       1.484
# ar.L2.D2.Confirmed    -0.4527      0.138     -3.285      0.001      -0.723      -0.183
# ma.L1.D2.Confirmed    -1.9125      0.075    -25.475      0.000      -2.060      -1.765
# ma.L2.D2.Confirmed     1.0000      0.075     13.392      0.000       0.854       1.146
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.3727           -0.5698j            1.4862           -0.0626
# AR.2            1.3727           +0.5698j            1.4862            0.0626
# MA.1            0.9563           -0.2925j            1.0000           -0.0472
# MA.2            0.9563           +0.2925j            1.0000            0.0472
# -----------------------------------------------------------------------------
# """

# %%
pred = results.forecast(steps=30)
pred
# Out:
# (array([ 97126.23170264, 102785.68831897, 108635.47987553, 114562.76326004,
#         120518.68681951, 126493.61945933, 132497.70653015, 138547.91739497,
#         144660.74979999, 150849.02605583, 157121.21390885, 163482.03286806,
#         169933.51523392, 176476.05032473, 183109.20197331, 189832.2518357 ,
#         196644.50456371, 203545.4211332 , 210534.64639936, 217611.98298539,
#         224777.3463553 , 232030.72079622, 239372.12504922, 246801.58952024,
#         254319.14351554, 261924.80969384, 269618.60294969, 277400.53153725,
#         285270.59897245, 293228.80588838]),
#  array([  649.49352014,  1080.92767256,  1402.38511046,  1660.80735754,
#          1902.75483868,  2166.1786529 ,  2479.86084485,  2862.30503214,
#          3321.16191238,  3855.21674418,  4458.05785986,  5121.47115256,
#          5837.58461922,  6599.82366681,  7403.1067107 ,  8243.67064127,
#          9118.77307423, 10026.39829185, 10965.01825496, 11933.41947304,
#         12930.58794244, 13955.63815227, 15007.77216837, 16086.25741716,
#         17190.41502547, 18319.61347365, 19473.26453246, 20650.81995218,
#         21851.76827786, 23075.63164302]),
#  array([[ 95853.24779496,  98399.21561032],
#         [100667.10901085, 104904.26762709],
#         [105886.85556656, 111384.10418449],
#         [111307.64065401, 117817.88586607],
#         [116789.3558643 , 124248.01777472],
#         [122247.98731556, 130739.2516031 ],
#         [127637.26858758, 137358.14447272],
#         [132937.90261921, 144157.93217073],
#         [138151.3920649 , 151170.10753508],
#         [143292.94008465, 158405.11202701],
#         [148383.58106252, 165858.84675518],
#         [153444.13386118, 173519.93187494],
#         [158492.05962354, 181374.97084429],
#         [163540.63363347, 189411.46701598],
#         [168599.37944663, 197619.02449998],
#         [173674.95427839, 205989.54939301],
#         [178772.03775503, 214516.97137239],
#         [183894.04158652, 223196.80067988],
#         [189043.60552982, 232025.6872689 ],
#         [194222.91060582, 241001.05536495],
#         [199433.85968919, 250120.83302142],
#         [204678.17263651, 259383.26895593],
#         [209957.43211104, 268786.8179874 ],
#         [215273.10433656, 278330.07470392],
#         [220626.54918632, 288011.73784476],
#         [226019.02707479, 297830.59231289],
#         [231451.70580466, 307785.50009473],
#         [236925.66817977, 317875.39489474],
#         [242441.92014932, 328099.27779558],
#         [248001.39894755, 338456.21282921]]))

# %%
import warnings
import itertools
warnings.filterwarnings("ignore")

# %%
p = d = q = range(0, 3)
pdq = list(itertools.product(p, d, q))
seasonal_pdq = [(x[0], x[1], x[2], 30) for x in list(itertools.product(p, d, q))]
y = df[campo]
aic_list = list()
param_list = list()
param_s_list = list()
# for param in pdq:
param = test
for param_seasonal in seasonal_pdq:
    try:
        results = sm.tsa.statespace.SARIMAX(
                        y,
                        order=(2,2,2),
                        seasonal_order=param_seasonal,
                        enforce_stationarity=False,
                        enforce_invertibility=False
        ).fit()
        print(f'ARIMA{param}x{param_seasonal} - AIC:{results.aic}')
        param_list.append(param)
        param_s_list.append(param_seasonal)
        aic_list.append(results.aic)
    except: 
        continue

# %%
best = aic_list.index(min(aic_list))
print(f'SARIMA{param_list[best]}x{param_s_list[best]} - AIC:{aic_list[best]}')

# %%
y = df[campo]
param_s_list_best=(1,0,1,30)
# param_s_list_best=param_s_list[best]
mod = sm.tsa.statespace.SARIMAX(
                                y,
                                order=test,
                                seasonal_order=param_s_list_best,
                                enforce_stationarity=False,
                                enforce_invertibility=False
)
# print(f'SARIMA{param_list[best]}x{param_s_list_best} - AIC:{aic_list[best]}')
results = mod.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                            Confirmed   No. Observations:                   58
# Model:             SARIMAX(2, 2, 2)x(1, 0, [1], 30)   Log Likelihood                -191.923
# Date:                              Mon, 04 May 2020   AIC                            397.846
# Time:                                      11:27:09   BIC                            405.795
# Sample:                                  02-25-2020   HQIC                           399.845
#                                        - 04-22-2020
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.1910      2.275      0.524      0.601      -3.268       5.650
# ar.L2         -0.2869      2.108     -0.136      0.892      -4.418       3.844
# ma.L1         -1.9664      4.908     -0.401      0.689     -11.587       7.654
# ma.L2          0.9811      4.969      0.197      0.843      -8.758      10.720
# ar.S.L30       2.9047      6.470      0.449      0.653      -9.776      15.585
# ma.S.L30       0.9724      7.795      0.125      0.901     -14.306      16.251
# sigma2      6.374e+05    1.6e-05   3.98e+10      0.000    6.37e+05    6.37e+05
# ===================================================================================
# Ljung-Box (Q):                       18.67   Jarque-Bera (JB):                 0.15
# Prob(Q):                              0.67   Prob(JB):                         0.93
# Heteroskedasticity (H):               3.47   Skew:                             0.18
# Prob(H) (two-sided):                  0.10   Kurtosis:                         2.83
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 4.15e+27. Standard errors may be unstable.
# """

# %%
results.plot_diagnostics(figsize=(30, 8))
plt.title('SARIMA')
if print_campo == 's':
    g += 1
    plt.savefig('ts\\0'+str(g)+'-'+campo+'_'+data+'.png', dpi=150)

# %%
pred = results.get_prediction(start=pd.to_datetime(first), dynamic=False)
pred_ci = pred.conf_int()
ax = y['2020':].plot(label='observed')
pred.predicted_mean.plot(ax=ax, label='Forecast', alpha=.7, figsize=figsize)
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.2)
ax.set_xlabel('Date')
ax.set_ylabel(campo)
plt.legend()
plt.title('Adjustment of the SARIMAX model')
if print_campo == 's':
    g += 1
    plt.savefig('ts\\0'+str(g)+'-'+campo+'_'+data+'.png', dpi=150)

# %%
y_forecasted = pred.predicted_mean
y_truth = y[first:]
mse = ((y_forecasted - y_truth) ** 2).mean()
print(f'The Mean Squared Error is {round(mse, 2)}')
print(f'The Root Mean Squared Error is {round(np.sqrt(mse), 2)}')
# Out:
# The Mean Squared Error is 735938.6
# The Root Mean Squared Error is 857.87

# %%
pred_uc = results.get_forecast(steps=30)
pred_ci = pred_uc.conf_int()
ax = y.plot(label='Observed', figsize=figsize)
pred_uc.predicted_mean.plot(ax=ax, label='Forecast')
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.25)
ax.set_xlabel('Date')
ax.set_ylabel(campo)
upper = round(pred_uc.conf_int()['upper Confirmed'].tail(1).values[0], 2)
lower = round(pred_uc.conf_int()['lower Confirmed'].tail(1).values[0], 2)
plt.text(x='2020-02-26', y=lower-100000, s=
    'Lower: ' + str(lower) +'\n'+
    'Upper: ' + str(upper)
)
plt.legend()
plt.title('SARIMA model forecast for day to ' + last)
if print_campo == 's':
    g += 1
    plt.savefig('ts\\0'+str(g)+'-'+campo+'_'+data+'.png', dpi=150)

# %%
pred_ci
# Out:
#             lower Confirmed  upper Confirmed
# 2020-04-23     94706.225337     98475.962019
# 2020-04-24    100261.736199    106989.151229
# 2020-04-25    105578.487724    114588.773114
# 2020-04-26    111804.942468    122488.278068
# 2020-04-27    116905.032371    129261.268884
# 2020-04-28    121520.221856    135481.304466
# 2020-04-29    127057.241172    142570.361571
# 2020-04-30    137282.859104    154332.640922
# 2020-05-01    146785.892469    165390.332442
# 2020-05-02    156593.618080    176795.274797
# 2020-05-03    165871.846404    187731.048916
# 2020-05-04    175333.179794    198922.812077
# 2020-05-05    184058.320742    209459.564407
# 2020-05-06    190835.567292    218134.469804
# 2020-05-07    204606.370175    233891.194323
# 2020-05-08    220722.045790    252081.310930
# 2020-05-09    234869.374671    268390.470585
# 2020-05-10    247951.778389    283720.032219
# 2020-05-11    255649.379274    293747.469519
# 2020-05-12    266675.032360    307182.659841
# 2020-05-13    276753.519231    319747.255144
# 2020-05-14    290488.978179    336042.211013
# 2020-05-15    313241.672118    361424.591696
# 2020-05-16    327620.502386    378500.181372
# 2020-05-17    350290.351797    403931.356113
# 2020-05-18    369708.485005    426174.914256
# 2020-05-19    382251.438946    441610.331980
# 2020-05-20    394558.039326    456877.431016
# 2020-05-21    412734.760684    478053.608712
# 2020-05-22    427764.957010    496005.344116
